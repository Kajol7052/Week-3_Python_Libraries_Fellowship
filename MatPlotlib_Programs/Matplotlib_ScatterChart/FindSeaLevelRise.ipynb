# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('data.csv')
time = data['Time']
sea_level = data['GMSL']
plt.scatter(time, sea_level, edgecolors='r', facecolors='k', alpha=0.8, s=70)
plt.xlabel('Time')
plt.ylabel('GMSL')
plt.title('Sea level rise')
plt.show()
