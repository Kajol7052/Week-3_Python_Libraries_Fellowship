# %%
import matplotlib.pyplot as plt

class DrawLine:
    def draw_line_from_text_file(self):
        """
        draw a line using given axis values taken from a text file,
        with suitable label in the x axis, y axis and a title
        """
        with open("text.txt") as my_file:
            my_data = my_file.read()
        my_data = my_data.split('\n')
        x = [int(row.split(' ')[0]) for row in data] # x-axis value
        y = [int(row.split(' ')[1]) for row in data] # y-axis value
        plt.plot(x, y, marker='^', color='peru')
        plt.xlabel('x-axis')
        plt.ylabel('y-axis')
        plt.title('Draw line from text file')
        plt.show()
        
if __name__ == "__main__":
    Draw = DrawLine()
    Draw.draw_line_from_text_file()
