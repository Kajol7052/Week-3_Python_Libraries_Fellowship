# %%
import matplotlib.pyplot as plt
import numpy as np
  
class GivenLinePoints:
    
    def given_line_points(self):
        """
        function to draw a line using given axis values with 
        suitable label in the x axis, y axis and a title
        """
        xpoints = np.array([1, 2, 3])
        ypoints =  np.array([2, 4, 1])
        plt.plot(xpoints, ypoints) # plot line 
        plt.xlabel('x-axis') # set x-axis label 
        plt.ylabel('y-axis') # set y-axis label
        plt.title('Draw line with given values.') # set title
        plt.show() # display figure/graph

        
if __name__ == "__main__":
    Draw = GivenLinePoints()
    Draw.given_line_points()
